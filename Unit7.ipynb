# %%
import csv

try:
    f = open('C:/Users/wtime/Desktop/Python/unit7.csv','r')
    data = csv.reader(f)
    header = next(data)
    print(header)
    #for row in data:        
    #    print(row)
    
    f.close()
except:
    
    print('에러발생')
# Out:
# ['행정구역', '2019년05월_계_총인구수', '2019년05월_계_연령구간인구수', '2019년05월_계_0세', '2019년05월_계_1세', '2019년05월_계_2세', '2019년05월_계_3세', '2019년05월_계_4세', '2019년05월_계_5세', '2019년05월_계_6세', '2019년05월_계_7세', '2019년05월_계_8세', '2019년05월_계_9세', '2019년05월_계_10세', '2019년05월_계_11세', '2019년05월_계_12세', '2019년05월_계_13세', '2019년05월_계_14세', '2019년05월_계_15세', '2019년05월_계_16세', '2019년05월_계_17세', '2019년05월_계_18세', '2019년05월_계_19세', '2019년05월_계_20세', '2019년05월_계_21세', '2019년05월_계_22세', '2019년05월_계_23세', '2019년05월_계_24세', '2019년05월_계_25세', '2019년05월_계_26세', '2019년05월_계_27세', '2019년05월_계_28세', '2019년05월_계_29세', '2019년05월_계_30세', '2019년05월_계_31세', '2019년05월_계_32세', '2019년05월_계_33세', '2019년05월_계_34세', '2019년05월_계_35세', '2019년05월_계_36세', '2019년05월_계_37세', '2019년05월_계_38세', '2019년05월_계_39세', '2019년05월_계_40세', '2019년05월_계_41세', '2019년05월_계_42세', '2019년05월_계_43세', '2019년05월_계_44세', '2019년05월_계_45세', '2019년05월_계_46세', '2019년05월_계_47세', '2019년05월_계_48세', '2019년05월_계_49세', '2019년05월_계_50세', '2019년05월_계_51세', '2019년05월_계_52세', '201
# ...

# %%
import csv
try:
    f = open('C:/Users/wtime/Desktop/Python/unit7.csv','r')
    data = csv.reader(f)
    header = next(data)
    #print(header)
    
    result=[]
    for row in data:     
        #1
        #search='경기도 안양시 동안구 평촌동(4117357000)'
        #if row[0]==search:
        #    print(row)
        #2
        search='평촌동'
        if search in row[0]:
            for i in row[3:]:
                #print(i)
                result.append(int(i))
        
    f.close()
    print(result)
except:
    
    print('에러발생')
# Out:
# [71, 111, 118, 156, 161, 139, 181, 225, 187, 179, 205, 219, 188, 168, 183, 172, 167, 176, 223, 206, 234, 253, 274, 252, 266, 250, 241, 219, 203, 149, 146, 156, 161, 150, 168, 203, 233, 250, 245, 247, 239, 272, 262, 273, 277, 309, 292, 310, 361, 325, 354, 332, 346, 318, 346, 271, 284, 259, 273, 255, 196, 176, 179, 169, 130, 96, 106, 98, 84, 91, 70, 64, 75, 64, 55, 42, 57, 58, 55, 57, 52, 55, 53, 44, 34, 21, 20, 15, 15, 9, 8, 6, 4, 2, 7, 0, 0, 0, 2, 1, 3]

# %%
import csv
import matplotlib.pyplot as plt

try:
    f = open('C:/Users/wtime/Desktop/Python/unit7.csv','r')
    data = csv.reader(f)
    header = next(data)
    #print(header)
    
    result=[]
    for row in data:     
        #1
        #search='경기도 안양시 동안구 평촌동(4117357000)'
        #if row[0]==search:
        #    print(row)
        #2
        search='평촌동'
        if search in row[0]:
            for i in row[3:]:
                #print(i)
                result.append(int(i))
        
    f.close()
    
    plt.style.use('ggplot')
    plt.plot(result)
    plt.show()
    
    #print(result)
except:
    
    print('에러발생')

# %%
import csv
import matplotlib.pyplot as plt

try:
    f = open('C:/Users/wtime/Desktop/Python/unit7.csv','r')
    data = csv.reader(f)
    header = next(data)
    #print(header)
    
    result=[]
    search=input('검색하고 싶은 동을 입력하세요.')
    for row in data:     
        #1
        #search='경기도 안양시 동안구 평촌동(4117357000)'
        #if row[0]==search:
        #    print(row)
        #2
        
        if search in row[0]:
            for i in row[3:]:
                #print(i)
                result.append(int(i))
        
    f.close()
    
    plt.style.use('ggplot')
    plt.plot(result)
    plt.show()
    
    #print(result)
except:
    
    print('에러발생')
# Out:
# 검색하고 싶은 동을 입력하세요.평촌동
