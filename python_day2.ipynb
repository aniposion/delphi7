# %% [markdown]
# ## 마크다운은 코드가 아니라 글을쓰는곳입니다 하하하
#
# ![11.jpg](attachment:11.jpg)
#
# # h1
# ## h2
# ### h3
# #### h4
# ##### h5
# ###### h6

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|

# %% [markdown]
# $e^{i\pi} + 1 = 0$
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/EchHMS7UgMw" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
a = [1,2,3,4,5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a[1]
# Out:
# 2
